# %%
import numpy  as np
import matplotlib.pyplot as plt

T300_LeadingLog = np.loadtxt('Fixed T 0.3 p from 0.8 to 4 Leading Log photon emission calc.txt')
T500_LeadingLog = np.loadtxt('Fixed T 0.5 p from 0.8 to 4 Leading Log photon emission calc.txt')
T300_LeadingOrder = np.loadtxt('Fixed T 0.3 p from 0.8 to 4 Leading Order photon emission calc.txt')
T500_LeadingOrder = np.loadtxt('Fixed T 0.5 p from 0.8 to 4 Leading Order photon emission calc.txt')

T300_LLmomentum = T300_LeadingLog[:,0]
T300_LLrate = T300_LeadingLog[:,1]
T500_LLmomentum = T500_LeadingLog[:,0]
T500_LLrate = T500_LeadingLog[:,1]

T300_LOmomentum = T300_LeadingOrder[:,0]
T300_LOrate = T300_LeadingOrder[:,1]
T500_LOmomentum = T500_LeadingOrder[:,0]
T500_LOrate = T500_LeadingOrder[:,1]

plt.plot(T300_LLmomentum,T300_LLrate,marker='.',color='r',label='LL T=300 MeV')
plt.plot(T500_LLmomentum,T500_LLrate,marker='.',linestyle='dashed',color='r',label='LL T=500 MeV')
plt.plot(T300_LOmomentum,T300_LOrate,marker='.',color='b',label='LO T=300 MeV')
plt.plot(T500_LOmomentum,T500_LOrate,marker='.',linestyle='dashed',color='b',label='LO T=500 MeV')

plt.xlabel('$p_T$ (GeV/c)')
plt.ylabel('$ E d\Gamma_\gamma/dp^3 (1/GeV^{-2}fm^{-4})$')
plt.title('Leading Log vs Leading Order Photon Emission Spectra')
plt.yscale('log')
plt.legend()
plt.show()
#Compares nicely with existing data from Kapusta and Aurenche
#The drop off with Leading Log is barely visible, but it can be seen
#The exponential decay of the Leading Order is also barely visible, but still seen

# %%
import numpy  as np
import matplotlib.pyplot as plt

T300_LeadingLog = np.loadtxt('Fixed T 0.3 p from 0.1 to 4.1 Leading Log photon emission calc.txt')
T500_LeadingLog = np.loadtxt('Fixed T 0.5 p from 0.1 to 4.1 Leading Log photon emission calc.txt')
T300_LeadingOrder = np.loadtxt('Fixed T 0.3 p from 0.1 to 4.1 Leading Order photon emission calc.txt')
T500_LeadingOrder = np.loadtxt('Fixed T 0.5 p from 0.1 to 4.1 Leading Order photon emission calc.txt')

T300_LLmomentum = T300_LeadingLog[:,0]
T300_LLrate = T300_LeadingLog[:,1]
T500_LLmomentum = T500_LeadingLog[:,0]
T500_LLrate = T500_LeadingLog[:,1]

T300_LOmomentum = T300_LeadingOrder[:,0]
T300_LOrate = T300_LeadingOrder[:,1]
T500_LOmomentum = T500_LeadingOrder[:,0]
T500_LOrate = T500_LeadingOrder[:,1]

plt.plot(T300_LLmomentum,T300_LLrate,marker='.',color='r',label='LL T=300 MeV')
plt.plot(T500_LLmomentum,T500_LLrate,marker='.',linestyle='dashed',color='r',label='LL T=500 MeV')
plt.plot(T300_LOmomentum,T300_LOrate,marker='.',color='b',label='LO T=300 MeV')
plt.plot(T500_LOmomentum,T500_LOrate,marker='.',linestyle='dashed',color='b',label='LO T=500 MeV')

plt.xlabel('$p_T$ (GeV)')
plt.ylabel('$ E d\Gamma_\gamma/dp^3$')
plt.title('Leading Log vs Leading Order Photon Emission Spectra')
plt.yscale('log')
plt.legend()
plt.show()
# I shifted the range to be between 0.1<p<4.1, and we can see
# that the Leading Log does not allow for values that low since the 
# emission rate is in the negatives, and negative log is undefined
# So the best range is the one from before (0.8<p<4)

# %%
import numpy  as np
import matplotlib.pyplot as plt

T300_LeadingLogThermal = np.loadtxt('Fixed T 0.3 p from 0.8 to 4 tau from 0.7 to 20 Leading Log thermal photon production calc.txt')
T500_LeadingLogThermal = np.loadtxt('Fixed T 0.5 p from 0.8 to 4 tau from 0.7 to 20 Leading Log thermal photon production calc.txt')
T300_LeadingOrderThermal = np.loadtxt('Fixed T 0.3 p from 0.8 to 4 tau from 0.7 to 20 Leading Order thermal photon production calc.txt')
T500_LeadingOrderThermal = np.loadtxt('Fixed T 0.5 p from 0.8 to 4 tau from 0.7 to 20 Leading Order thermal photon production calc.txt')

T300_LLThermalmomentum = T300_LeadingLogThermal[:,0]
T300_LLThermalrate = T300_LeadingLogThermal[:,1]
T500_LLThermalmomentum = T500_LeadingLogThermal[:,0]
T500_LLThermalrate = T500_LeadingLogThermal[:,1]

T300_LOThermalmomentum = T300_LeadingOrderThermal[:,0]
T300_LOThermalrate = T300_LeadingOrderThermal[:,1]
T500_LOThermalmomentum = T500_LeadingOrderThermal[:,0]
T500_LOThermalrate = T500_LeadingOrderThermal[:,1]

plt.plot(T300_LLThermalmomentum,T300_LLThermalrate,marker='.',color='r',label='LL T=300 MeV')
plt.plot(T500_LLThermalmomentum,T500_LLThermalrate,marker='.',linestyle='dashed',color='r',label='LL T=500 MeV')
plt.plot(T300_LOThermalmomentum,T300_LOThermalrate,marker='.',color='b',label='LO T=300 MeV')
plt.plot(T500_LOThermalmomentum,T500_LOThermalrate,marker='.',linestyle='dashed',color='b',label='LO T=500 MeV')

plt.xlabel('$p_T$ (GeV/c)')
plt.ylabel('$ E dN\gamma/dp^3 (GeV^{-2})$')
plt.title('Leading Log vs Leading Order Thermal Photon Production Spectra')
plt.yscale('log')
plt.legend()
plt.show()

#This plot looks a lot like the photon emission plot, but the scale is definitely higher, why is this?

# %%
import numpy  as np
import matplotlib.pyplot as plt

T300_LeadingLogThermal1 = np.loadtxt('Fixed T 0.3 p from 0.8 to 4 tau from 0 to 10 Leading Log thermal photon emission.txt')
T500_LeadingLogThermal1 = np.loadtxt('Fixed T 0.5 p from 0.8 to 4 tau from 0 to 10 Leading Log thermal photon emission.txt')
T300_LeadingOrderThermal1 = np.loadtxt('Fixed T 0.3 p from 0.8 to 4 tau from 0 to 10 Leading Order thermal photon emission.txt')
T500_LeadingOrderThermal1 = np.loadtxt('Fixed T 0.5 p from 0.8 to 4 tau from 0 to 10 Leading Order thermal photon emission.txt')

T300_LLThermalmomentum1 = T300_LeadingLogThermal1[:,0]
T300_LLThermalrate1 = T300_LeadingLogThermal1[:,1]
T500_LLThermalmomentum1 = T500_LeadingLogThermal1[:,0]
T500_LLThermalrate1 = T500_LeadingLogThermal1[:,1]

T300_LOThermalmomentum1 = T300_LeadingOrderThermal1[:,0]
T300_LOThermalrate1 = T300_LeadingOrderThermal1[:,1]
T500_LOThermalmomentum1 = T500_LeadingOrderThermal1[:,0]
T500_LOThermalrate1 = T500_LeadingOrderThermal1[:,1]

plt.plot(T300_LLThermalmomentum1,T300_LLThermalrate1,marker='.',color='r',label='LL $dN_{\gamma}$ T=300 MeV')
plt.plot(T500_LLThermalmomentum1,T500_LLThermalrate1,marker='.',linestyle='dashed',color='r',label='LL $dN_{\gamma}$ T=500 MeV')
plt.plot(T300_LOThermalmomentum1,T300_LOThermalrate1,marker='.',color='b',label='LO $dN_{\gamma}$ T=300 MeV')
plt.plot(T500_LOThermalmomentum1,T500_LOThermalrate1,marker='.',linestyle='dashed',color='b',label='LO $dN_{\gamma}$ T=500 MeV')

plt.xlabel('$p_T$ (GeV)')
plt.ylabel('$ E dN\gamma/dp^3$')
plt.title('Leading Log vs Leading Order Thermal Photon Production Spectra')
plt.yscale('log')
plt.legend()
plt.show()

# %%
import numpy  as np
import matplotlib.pyplot as plt


# T300_BjorkenLLThermalConformal = np.loadtxt('T =0.3 p from 0.8 to 4 tau from 0.7 to 20 Bjorken Conformal Thermal Photon Emission Calculations.txt')
# T300_BjorkenLLThermalQCD = np.loadtxt('T =0.3 p from 0.8 to 4 tau from 0.7 to 20 Bjorken QCD Thermal Photon Emission Calculations.txt')
T500_BjorkenLLThermalConformal = np.loadtxt('T =0.5 p from 0.8 to 4 tau from 0.7 to 20 Bjorken Conformal Thermal Photon Emission Calculations.txt')
T500_BjorkenLLThermalQCD = np.loadtxt('T =0.5 p from 0.8 to 4 tau from 0.7 to 20 Bjorken QCD Thermal Photon Emission Calculations.txt')



# T300_BjorkLLThermConfMomentum = T300_BjorkenLLThermalConformal[:,0]
# T300_BjorkLLThermConfRate = T300_BjorkenLLThermalConformal[:,1]
T500_BjorkLLThermConfMomentum = T500_BjorkenLLThermalConformal[:,0]
T500_BjorkLLThermConfRate = T500_BjorkenLLThermalConformal[:,1]

# T300_BjorkLLThermQCDMomentum = T300_BjorkenLLThermalQCD[:,0]
# T300_BjorkLLThermQCDRate = T300_BjorkenLLThermalQCD[:,1]
T500_BjorkLLThermQCDMomentum = T500_BjorkenLLThermalQCD[:,0]
T500_BjorkLLThermQCDRate = T500_BjorkenLLThermalQCD[:,1]


# plt.plot(T300_BjorkLLThermConfMomentum,T300_BjorkLLThermConfRate, marker='.',color='purple',label='Bjorken Conf LL')
# plt.plot(T300_BjorkLLThermQCDMomentum,T300_BjorkLLThermQCDRate,marker='.',color='green',label='Bjorken QCD LL')
plt.plot(T500_BjorkLLThermConfMomentum,T500_BjorkLLThermConfRate, marker='.',color='purple',label='Bjorken Conf LL')
plt.plot(T500_BjorkLLThermQCDMomentum,T500_BjorkLLThermQCDRate,marker='.',color='green',label='Bjorken QCD LL')
PHENIX_Momentum, PHENIX_Rate, PHENIX_stat_err, PHENIX_syst_err=np.loadtxt('PHENIX data for Thermal Photons.txt').T
plt.errorbar(PHENIX_Momentum,PHENIX_Rate, yerr=np.sqrt(PHENIX_stat_err**2+PHENIX_syst_err**2), fmt='*',color='black',label='PHENIX $T_{eff}=300-400$ MeV/c')

plt.xlabel('$p_T$ (GeV/c)')
plt.ylabel('$ E dN\gamma/dp^3 (GeV^{-2})$')
plt.title('Bjorken Thermal Photon Production Spectra at T~500MeV')
# plt.title('Bjorken Thermal Photon Production Spectra at T~300MeV')
plt.yscale('log')
plt.legend()
plt.show()
